# %%
# ===============================
# 1. Install & Import Libraries
# ===============================
# !pip install -q transformers torch scikit-learn pandas tqdm

import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from transformers import DistilBertTokenizer

# ===============================
# 2. Load & Preprocess BharatFakeNewsKosh
# ===============================
df_bharat = pd.read_csv("BharatFakeNewsKosh.csv")
df_bharat = df_bharat.rename(columns={"news": "text", "category": "label"})
df_bharat['label'] = df_bharat['label'].map({'fake': 0, 'real': 1})

# ===============================
# 3. Load & Preprocess ISOT Dataset
# ===============================
df_isot = pd.read_csv("ISOT_dataset.csv")
df_isot = df_isot.rename(columns={"content": "text", "class": "label"})
df_isot['label'] = df_isot['label'].map({'fake': 0, 'real': 1})

# ===============================
# 4. Load & Preprocess Indian Fake News Dataset
# ===============================
df_indian = pd.read_csv("IndianFakeNews.csv")
df_indian = df_indian.rename(columns={"news": "text", "category": "label"})
df_indian['label'] = df_indian['label'].map({'fake': 0, 'real': 1})

# ===============================
# 5. Merge All Datasets
# ===============================
combined_df = pd.concat([df_bharat, df_isot, df_indian], axis=0).reset_index(drop=True)
print("Merged dataset shape:", combined_df.shape)
print(combined_df['label'].value_counts())

# ===============================
# 6. Train-Test Split
# ===============================
train_texts, test_texts, train_labels, test_labels = train_test_split(
    combined_df["text"].tolist(),
    combined_df["label"].tolist(),
    test_size=0.2,
    random_state=42,
    stratify=combined_df["label"]
)

# ===============================
# 7. Tokenization with DistilBERT (max_length=512)
# ===============================
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")

train_encodings = tokenizer(train_texts, truncation=True, padding=True, max_length=512)
test_encodings = tokenizer(test_texts, truncation=True, padding=True, max_length=512)

# ===============================
# 8. Save Tokenized Data
# ===============================
torch.save((train_encodings, torch.tensor(train_labels)), "data/train_tokenized.pt")
torch.save((test_encodings, torch.tensor(test_labels)), "data/test_tokenized.pt")

print("✅ Preprocessing completed. Tokenized datasets saved in 'data/' folder")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1287275620.py in <cell line: 0>()
#      12 # 2. Load & Preprocess BharatFakeNewsKosh
#      13 # ===============================
# ---> 14 df_bharat = pd.read_csv("BharatFakeNewsKosh.csv")
#      15 df_bharat = df_bharat.rename(columns={"news": "text", "category": "label"})
#      16 df_bharat['label'] = df_bharat['label'].map({'fake': 0, 'real': 1})
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1241535617.py in <cell line: 0>()
#      12 # 2. Preprocess BharatFakeNewsKosh
#      13 # ===============================
# ---> 14 df_bharat = pd.read_csv("BharatFakeNewsKosh.csv")
#      15 df_bharat = df_bharat[["news", "category"]]  # only keep relevant columns
#      16 df_bharat = df_bharat.rename(columns={"news": "text", "category": "label"})
#
# ...

# %%
# ===============================
# 1. Install & Import Libraries
# ===============================
# !pip install -q transformers torch scikit-learn pandas tqdm

import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from transformers import DistilBertTokenizer
import os

# ===============================
# 2. Preprocess BharatFakeNewsKosh
# ===============================
df_bharat = pd.read_csv("bharatfakenewskosh (3).csv")
# Keep only relevant columns: text + label
df_bharat = df_bharat[["news", "category"]]
df_bharat = df_bharat.rename(columns={"news": "text", "category": "label"})
df_bharat['label'] = df_bharat['label'].map({'fake': 0, 'real': 1})
df_bharat = df_bharat.dropna(subset=["text", "label"])
print("BharatFakeNewsKosh shape:", df_bharat.shape)

# ===============================
# 3. Preprocess Indian Fake News Dataset
# ===============================
df_indian = pd.read_csv("news_dataset.csv")
df_indian = df_indian[["news", "category"]]
df_indian = df_indian.rename(columns={"news": "text", "category": "label"})
df_indian['label'] = df_indian['label'].map({'fake': 0, 'real': 1})
df_indian = df_indian.dropna(subset=["text", "label"])
print("Indian Fake News Dataset shape:", df_indian.shape)

# ===============================
# 4. Preprocess ISOT Dataset (Fake + True)
# ===============================
df_fake = pd.read_csv("Fake.csv")
df_fake['label'] = 0  # fake
df_true = pd.read_csv("True.csv")
df_true['label'] = 1  # real

# Combine ISOT datasets
df_isot = pd.concat([df_fake, df_true], axis=0).reset_index(drop=True)
# Keep only 'text' column and 'label'
if 'text' not in df_isot.columns:
    raise ValueError("ISOT datasets must contain 'text' column")
df_isot = df_isot[['text', 'label']].dropna(subset=['text', 'label'])
print("ISOT Dataset shape:", df_isot.shape)

# ===============================
# 5. Merge All Datasets
# ===============================
combined_df = pd.concat([df_bharat, df_indian, df_isot], axis=0).reset_index(drop=True)
print("Merged dataset shape:", combined_df.shape)
print(combined_df['label'].value_counts())

# ===============================
# 6. Train-Test Split
# ===============================
train_texts, test_texts, train_labels, test_labels = train_test_split(
    combined_df['text'].tolist(),
    combined_df['label'].tolist(),
    test_size=0.2,
    random_state=42,
    stratify=combined_df['label']
)

# ===============================
# 7. Tokenization with DistilBERT (max_length=512)
# ===============================
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")

train_encodings = tokenizer(train_texts, truncation=True, padding=True, max_length=512)
test_encodings = tokenizer(test_texts, truncation=True, padding=True, max_length=512)

# ===============================
# 8. Save Tokenized Data
# ===============================
os.makedirs("data", exist_ok=True)
torch.save((train_encodings, torch.tensor(train_labels)), "data/train_tokenized.pt")
torch.save((test_encodings, torch.tensor(test_labels)), "data/test_tokenized.pt")

print("✅ Preprocessing completed. Tokenized datasets saved in 'data/' folder")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipython-input-1067372264.py in <cell line: 0>()
#      13 # 2. Preprocess BharatFakeNewsKosh
#      14 # ===============================
# ---> 15 df_bharat = pd.read_csv("bharatfakenewskosh (3).csv")
#      16 # Keep only relevant columns: text + label
#      17 df_bharat = df_bharat[["news", "category"]]
#
# ...

# %%
# ===============================
# 1. Install & Import Libraries
# ===============================
# !pip install -q transformers torch scikit-learn pandas tqdm

import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from transformers import DistilBertTokenizer
import os

# ===============================
# Helper function to safely load CSVs
# ===============================
def load_csv_safe(path):
    try:
        return pd.read_csv(path, encoding='utf-8')
    except UnicodeDecodeError:
        return pd.read_csv(path, encoding='latin1')

# ===============================
# 2. Preprocess BharatFakeNewsKosh
# ===============================
df_bharat = load_csv_safe("bharatfakenewskosh (3).csv")
df_bharat = df_bharat[["news", "category"]]
df_bharat = df_bharat.rename(columns={"news": "text", "category": "label"})
df_bharat['label'] = df_bharat['label'].map({'fake': 0, 'real': 1})
df_bharat = df_bharat.dropna(subset=["text", "label"])
print("BharatFakeNewsKosh shape:", df_bharat.shape)

# ===============================
# 3. Preprocess Indian Fake News Dataset
# ===============================
df_indian = load_csv_safe("news_dataset.csv")
df_indian = df_indian[["news", "category"]]
df_indian = df_indian.rename(columns={"news": "text", "category": "label"})
df_indian['label'] = df_indian['label'].map({'fake': 0, 'real': 1})
df_indian = df_indian.dropna(subset=["text", "label"])
print("Indian Fake News Dataset shape:", df_indian.shape)

# ===============================
# 4. Preprocess ISOT Dataset (Fake + True)
# ===============================
df_fake = load_csv_safe("Fake.csv")
df_fake['label'] = 0  # fake
df_true = load_csv_safe("True.csv")
df_true['label'] = 1  # real

df_isot = pd.concat([df_fake, df_true], axis=0).reset_index(drop=True)

# Keep only text + label columns
if 'text' not in df_isot.columns:
    raise ValueError("ISOT datasets must contain 'text' column")
df_isot = df_isot[['text', 'label']].dropna(subset=['text', 'label'])
print("ISOT Dataset shape:", df_isot.shape)

# ===============================
# 5. Merge All Datasets
# ===============================
combined_df = pd.concat([df_bharat, df_indian, df_isot], axis=0).reset_index(drop=True)
print("Merged dataset shape:", combined_df.shape)
print(combined_df['label'].value_counts())

# ===============================
# 6. Train-Test Split
# ===============================
train_texts, test_texts, train_labels, test_labels = train_test_split(
    combined_df['text'].tolist(),
    combined_df['label'].tolist(),
    test_size=0.2,
    random_state=42,
    stratify=combined_df['label']
)

# ===============================
# 7. Tokenization with DistilBERT (max_length=512)
# ===============================
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")

train_encodings = tokenizer(train_texts, truncation=True, padding=True, max_length=512)
test_encodings = tokenizer(test_texts, truncation=True, padding=True, max_length=512)

# ===============================
# 8. Save Tokenized Data
# ===============================
os.makedirs("data", exist_ok=True)
torch.save((train_encodings, torch.tensor(train_labels)), "data/train_tokenized.pt")
torch.save((test_encodings, torch.tensor(test_labels)), "data/test_tokenized.pt")

print("✅ Preprocessing completed. Tokenized datasets saved in 'data/' folder")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1825813772.py in <cell line: 0>()
#      23 # ===============================
#      24 df_bharat = load_csv_safe("bharatfakenewskosh (3).csv")
# ---> 25 df_bharat = df_bharat[["news", "category"]]
#      26 df_bharat = df_bharat.rename(columns={"news": "text", "category": "label"})
#      27 df_bharat['label'] = df_bharat['label'].map({'fake': 0, 'real': 1})
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
# ...

# %%
# ===============================
# 1. Install & Import Libraries
# ===============================
# !pip install -q transformers torch scikit-learn pandas tqdm

import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from transformers import DistilBertTokenizer
import os

# ===============================
# Helper function to safely load CSVs
# ===============================
def load_csv_safe(path):
    try:
        return pd.read_csv(path, encoding='utf-8')
    except UnicodeDecodeError:
        return pd.read_csv(path, encoding='latin1')

# ===============================
# 2. Preprocess Indian Fake News Dataset
# ===============================
df_indian = load_csv_safe("news_dataset.csv")
# The columns are already 'text' and 'label' based on variable inspection
# df_indian = df_indian[["news", "category"]] # This line is no longer needed
# df_indian = df_indian.rename(columns={"news": "text", "category": "label"}) # This line is no longer needed
df_indian['label'] = df_indian['label'].map({'fake': 0, 'real': 1})
df_indian = df_indian.dropna(subset=["text", "label"])
print("Indian Fake News Dataset shape:", df_indian.shape)

# ===============================
# 3. Preprocess ISOT Dataset (Fake + True)
# ===============================
df_fake = load_csv_safe("Fake.csv")
df_fake['label'] = 0  # fake
df_true = load_csv_safe("True.csv")
df_true['label'] = 1  # real

df_isot = pd.concat([df_fake, df_true], axis=0).reset_index(drop=True)

# Keep only text + label columns
if 'text' not in df_isot.columns:
    raise ValueError("ISOT datasets must contain 'text' column")
df_isot = df_isot[['text', 'label']].dropna(subset=['text', 'label'])
print("ISOT Dataset shape:", df_isot.shape)

# ===============================
# 4. Merge Datasets
# ===============================
combined_df = pd.concat([df_indian, df_isot], axis=0).reset_index(drop=True)
print("Merged dataset shape:", combined_df.shape)
print(combined_df['label'].value_counts())

# ===============================
# 5. Train-Test Split
# ===============================
train_texts, test_texts, train_labels, test_labels = train_test_split(
    combined_df['text'].tolist(),
    combined_df['label'].tolist(),
    test_size=0.2,
    random_state=42,
    stratify=combined_df['label']
)

# ===============================
# 6. Tokenization with DistilBERT (max_length=512)
# ===============================
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")

train_encodings = tokenizer(train_texts, truncation=True, padding=True, max_length=512)
test_encodings = tokenizer(test_texts, truncation=True, padding=True, max_length=512)

# ===============================
# 7. Save Tokenized Data
# ===============================
os.makedirs("data", exist_ok=True)
torch.save((train_encodings, torch.tensor(train_labels)), "data/train_tokenized.pt")
torch.save((test_encodings, torch.tensor(test_labels)), "data/test_tokenized.pt")

print("✅ Preprocessing completed. Tokenized datasets saved in 'data/' folder")
# Out:
# Indian Fake News Dataset shape: (0, 2)
# ISOT Dataset shape: (44898, 2)
# Merged dataset shape: (44898, 2)
# label
# 0.0    23481
# 1.0    21417
# Name: count, dtype: int64
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# ...

# %%
# ====================================
# 0. Install Required Packages
# ====================================
# !pip install -q transformers torch scikit-learn tqdm

# ====================================
# 1. Imports
# ====================================
import torch
from torch.utils.data import Dataset, DataLoader
from torch.optim import AdamW
from transformers import DistilBertForSequenceClassification, DistilBertTokenizer, get_scheduler
from tqdm import tqdm
from sklearn.metrics import accuracy_score, classification_report

# ====================================
# 2. Load Tokenized Data Safely
# ====================================
from transformers import BatchEncoding

# Use safe_globals to allow BatchEncoding unpickling
with torch.serialization.safe_globals([BatchEncoding]):
    train_encodings, train_labels = torch.load("data/train_tokenized.pt", weights_only=False)
    test_encodings, test_labels = torch.load("data/test_tokenized.pt", weights_only=False)

# Ensure labels are tensors
if not isinstance(train_labels, torch.Tensor):
    train_labels = torch.tensor(train_labels)
if not isinstance(test_labels, torch.Tensor):
    test_labels = torch.tensor(test_labels)

# ====================================
# 3. Dataset Class
# ====================================
class NewsDataset(Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        item = {key: val[idx] for key, val in self.encodings.items()}
        item["labels"] = self.labels[idx]
        return item

train_dataset = NewsDataset(train_encodings, train_labels)
test_dataset = NewsDataset(test_encodings, test_labels)

# ====================================
# 4. DataLoaders
# ====================================
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=4, shuffle=False, pin_memory=True)

# ====================================
# 5. Load DistilBERT Model
# ====================================
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print("Using device:", device)

model = DistilBertForSequenceClassification.from_pretrained(
    "distilbert-base-uncased",
    num_labels=2
)
model.to(device)

# ====================================
# 6. Optimizer & Scheduler
# ====================================
optimizer = AdamW(model.parameters(), lr=5e-5)
num_training_steps = len(train_loader) * 3  # 3 epochs
lr_scheduler = get_scheduler(
    "linear", optimizer=optimizer, num_warmup_steps=0, num_training_steps=num_training_steps
)

# ====================================
# 7. Training Loop
# ====================================
epochs = 3
progress_bar = tqdm(range(num_training_steps))

model.train()
for epoch in range(epochs):
    for batch in train_loader:
        # Move batch items to the device
        batch = {k: v.to(device) for k, v in batch.items()}

        outputs = model(**batch)
        loss = outputs.loss

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        lr_scheduler.step()
        progress_bar.update(1)

    print(f"Epoch {epoch+1} completed with loss: {loss.item()}")

# ====================================
# 8. Evaluation
# ====================================
model.eval()
preds, labels_list = [], []

with torch.no_grad():
    for batch in test_loader:
        # Move batch items to the device
        batch = {k: v.to(device) for k, v in batch.items()}

        outputs = model(**batch)
        predictions = torch.argmax(outputs.logits, dim=-1)
        preds.extend(predictions.cpu().numpy())
        labels_list.extend(batch["labels"].cpu().numpy())

acc = accuracy_score(labels_list, preds)
print("🎯 Test Accuracy:", acc)
print("\nClassification Report:\n", classification_report(labels_list, preds, target_names=["Fake", "Real"]))

# ====================================
# 9. Save Model & Tokenizer
# ====================================
model.save_pretrained("saved_model_distilbert")
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")
tokenizer.save_pretrained("saved_model_distilbert")
print("✅ Model and tokenizer saved to 'saved_model_distilbert/'")
# Out:
# Using device: cuda
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#
#   0%|          | 0/26940 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1003493092.py in <cell line: 0>()
#      86     for batch in train_loader:
#      87         # Move batch items to the device
# ---> 88         batch = {k: v.to(device) for k, v in batch.items()}
#      89
#      90         outputs = model(**batch)
#
# AttributeError: 'list' object has no attribute 'to'

# %%
# ====================================
# 0. Install Required Packages
# ====================================
# !pip install -q transformers torch scikit-learn tqdm

# ====================================
# 1. Imports
# ====================================
import torch
from torch.utils.data import Dataset, DataLoader
from torch.optim import AdamW
from transformers import DistilBertForSequenceClassification, DistilBertTokenizer, get_scheduler, BatchEncoding
from tqdm import tqdm
from sklearn.metrics import accuracy_score, classification_report

# ====================================
# 2. Load Tokenized Data Safely
# ====================================
# Register BatchEncoding as safe for unpickling (PyTorch 2.6+)
torch.serialization.add_safe_globals([BatchEncoding])

# Load tokenized data
train_encodings, train_labels = torch.load("data/train_tokenized.pt", weights_only=False)
test_encodings, test_labels = torch.load("data/test_tokenized.pt", weights_only=False)

# Ensure labels are long tensors
train_labels = torch.tensor(train_labels, dtype=torch.long)
test_labels = torch.tensor(test_labels, dtype=torch.long)

# ====================================
# 3. Dataset Class
# ====================================
class NewsDataset(Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item["labels"] = self.labels[idx].long()  # Ensure labels are long
        return item

train_dataset = NewsDataset(train_encodings, train_labels)
test_dataset = NewsDataset(test_encodings, test_labels)

# ====================================
# 4. DataLoaders
# ====================================
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=4, shuffle=False, pin_memory=True)

# ====================================
# 5. Load DistilBERT Model
# ====================================
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print("Using device:", device)

model = DistilBertForSequenceClassification.from_pretrained(
    "distilbert-base-uncased",
    num_labels=2
)
model.to(device)

# ====================================
# 6. Optimizer & Scheduler
# ====================================
optimizer = AdamW(model.parameters(), lr=5e-5)
num_training_steps = len(train_loader) * 3  # 3 epochs
lr_scheduler = get_scheduler(
    "linear", optimizer=optimizer, num_warmup_steps=0, num_training_steps=num_training_steps
)

# ====================================
# 7. Training Loop
# ====================================
epochs = 3
progress_bar = tqdm(range(num_training_steps))

model.train()
for epoch in range(epochs):
    for batch in train_loader:
        batch = {k: v.to(device) for k, v in batch.items()}
        outputs = model(**batch)  # labels included in batch
        loss = outputs.loss

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        lr_scheduler.step()
        progress_bar.update(1)

    print(f"Epoch {epoch+1} completed with loss: {loss.item()}")

# ====================================
# 8. Evaluation
# ====================================
model.eval()
preds, labels_list = [], []

with torch.no_grad():
    for batch in test_loader:
        batch = {k: v.to(device) for k, v in batch.items()}
        outputs = model(**batch)
        predictions = torch.argmax(outputs.logits, dim=-1)
        preds.extend(predictions.cpu().numpy())
        labels_list.extend(batch["labels"].cpu().numpy())

acc = accuracy_score(labels_list, preds)
print("🎯 Test Accuracy:", acc)
print("\nClassification Report:\n", classification_report(labels_list, preds, target_names=["Fake", "Real"]))

# ====================================
# 9. Save Model & Tokenizer Locally
# ====================================
model.save_pretrained("saved_model_distilbert")
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")
tokenizer.save_pretrained("saved_model_distilbert")
print("✅ Model and tokenizer saved locally to 'saved_model_distilbert/'")
# Out:
# /tmp/ipython-input-1719583560.py:27: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   train_labels = torch.tensor(train_labels, dtype=torch.long)
# /tmp/ipython-input-1719583560.py:28: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   test_labels = torch.tensor(test_labels, dtype=torch.long)
# Using device: cuda
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#
#
# ...

# %%
# !zip -r saved_model_distilbert.zip saved_model_distilbert
from google.colab import files
files.download("saved_model_distilbert.zip")
# Out:
#   adding: saved_model_distilbert/ (stored 0%)
#   adding: saved_model_distilbert/model.safetensors (deflated 8%)
#   adding: saved_model_distilbert/vocab.txt (deflated 53%)
#   adding: saved_model_distilbert/config.json (deflated 45%)
#   adding: saved_model_distilbert/special_tokens_map.json (deflated 42%)
#   adding: saved_model_distilbert/tokenizer_config.json (deflated 75%)
